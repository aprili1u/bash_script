# %%
data = pd.read_csv('results_cleaned.csv', header=None, error_bad_lines=False)
print(data.iloc[1][4])
# Out:
# 12.59719052

# %%
import numpy as np
import seaborn as sns
import csv
import pandas as pd
import matplotlib.pyplot as plt

def plot(n1,n2,n3,line,title):
    X = [i for i in range (1,10000)]
    data = pd.read_csv('results_cleaned.csv', header=None, error_bad_lines=False)
    i = 0
    fig = plt.figure(figsize=(12, 7))
    for i in range (len(data)):
        dt = data.iloc[i]
        if (dt[0] == n1 or dt[0] == n2 or dt[0] == n3):
            i+=1
            if (dt[0] == n1 and dt[2] == line):
                plt.plot(list(dt[3:]),color= 'deepskyblue')
            if (dt[0] == n2 and dt[2] == line):
                plt.plot(list(dt[3:]),color= 'blue')
            if (dt[0] == n3 and dt[2] == line):
                plt.plot(list(dt[3:]),color= 'gold')

    plt.xlabel('Generations')
    plt.ylabel('Mean memory',labelpad=50)
    plt.title(title)
    plt.show()

# %%
plot(3,4,5,'Mean_Memory','32 nodes, 8 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(0,1,2,'Mean_Memory','32 nodes, 8 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(6,7,8,'Mean_Memory','32 nodes, 8 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(9,10,11,'Mean_Memory','32 nodes, 32 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(12,13,14,'Mean_Memory','32 nodes, 32 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(15,16,17,'Mean_Memory','32 nodes, 32 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(18,19,20,'Mean_Memory','128 nodes, 8 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(21,22,23,'Mean_Memory','128 nodes, 8 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(24,25,26,'Mean_Memory','128 nodes, 8 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(27,28,29,'Mean_Memory','128 nodes, 32 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(30,31,32,'Mean_Memory','128 nodes, 32 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(33,34,35,'Mean_Memory','128 nodes, 32 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(36,37,38,'Mean_Memory','128 nodes, 128 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(39,40,41,'Mean_Memory','128 nodes, 128 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(42,43,44,'Mean_Memory','128 nodes, 128 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(45,46,47,'Mean_Memory','512 nodes, 8 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(48,49,50,'Mean_Memory','512 nodes, 8 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(51,52,53,'Mean_Memory','512 nodes, 8 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')

# %%
plot(54,55,56,'Mean_Memory','512 nodes, 32 interaction partners , memory_cost 0.1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(57,58,59,'Mean_Memory','512 nodes, 32 interaction partners , memory_cost 1, gold 1024 interactions per node, blue 256 and light blue 64 ')
plot(60,61,62,'Mean_Memory','512 nodes, 32 interaction partners , memory_cost 5, gold 1024 interactions per node, blue 256 and light blue 64 ')
